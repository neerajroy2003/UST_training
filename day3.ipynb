# %%
lst=open('/Users/Administrator/Desktop/New folder')
lst.close()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 lst=open('/Users/Administrator/Desktop/New folder')
#       2 lst.close()
#
# File C:\Program Files\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: '/Users/Administrator/Desktop/New folder'

# %%
import os
os.getenv('/Users')
lst=open("my3.txt","w")
lst.write("hello world how are you")
lst.close()
lst=open("my3.txt","r")
lst.read()
# Out:
# 'hello world how are you'

# %%
lst.tell()
# Out:
# 23

# %%
lst.seek(2)
# Out:
# 2

# %%
lst.tell()
# Out:
# 2

# %%
lst.readline()
# Out:
# 'llo world how are you'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
#----------------------------------------------------------------------------------------------------------------

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
from datetime import datetime 
datetime.now()
# Out:
# datetime.datetime(2026, 2, 20, 11, 7, 49, 35304)

# %%
class Bank:
    bal=0 
    def __init__(self, name, account, mob):
        self.name=name
        self.account=account
        self.mob=mob
    def deposit(self, amount):
        Bank.bal+=amount 
    def withdraw(self, amount, acc):
        if acc==self.acc:
            if amount<=Bank.bal:
                print(f'collect rs{amount} thank you')
                Bank.avbal=Bank.avbal-amount 
            else:
                print("insufficient balance")
        else:
            print("incorrect account number")
div=Bank("ram",12345,9847747965)
div.deposit(391)
div.withdraw(272,65342)
print(Bank.bal)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 20
#      18 div=Bank("ram",12345,9847747965)
#      19 div.deposit(391)
# ---> 20 div.withdraw(2727,65342)
#      21 print(Bank.bal)
#
# Cell In[30], line 10, in Bank.withdraw(self, amount, acc)
#       9 def withdraw(self, amount, acc):
# ---> 10     if acc==self.acc:
#      11         if amount<=Bank.bal:
#      12             print(f'collect rs{amount} thank you')
#
# AttributeError: 'Bank' object has no attribute 'acc'
